# %%
print("Hello World")
# Out:
# Hello World

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model with 2 GPUs
results = model.train(data='data.yaml', epochs=50, imgsz=640, device="cpu")

# %%
# Validate model

from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train2/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.152  Python-3.12.3 torch-2.7.1+cpu CPU (AMD Ryzen 7 4700U with Radeon Graphics)
# Model summary (fused): 72 layers, 3,010,328 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.40.1 ms, read: 8.715.5 MB/s, size: 23.8 KB)
# val: Scanning C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-A
# C:\Users\mortrpestl\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:15<0
#                    all         99        261      0.401     0.0668     0.0748     0.0341
#                  Bread         14         24      0.099     0.0833     0.0763     0.0154
#                   Cake          1          1          1          0    0.00765    0.00153
#                  Dairy          4         14          0          0    0.00353    0.00181
#                  Drink         31         32      0.226      0.344      0.229      0.038
#                    Egg          1          2          1          0    0.00747    0.00299
#                   Fish          2          6          1          0          0          0
#                  Fruit         15         37      0.647      0.189      0.178     0.0605
#                Lasagne          1          1          1          0          0          0
#                 Legume          1          1          0          0          0          0
#                   Meat         16         36          0          0     0.0103    0.00293
#                 Noodle          7         11      0.158      0.273      0.288      0.154
#                    Nut          4          5          0          0          0          0
#                 Pastry          9          9      0.621      0.192       0.18     0.0755
#                  Pizza          2          3          0          0     0.0511     0.0262
#                 Potato          7         14          0          0     0.0128     0.0053
#                   Rice          4          7      0.169      0.143     0.0299    0.00633
#                  Sauce          2          2          0          0          0          0
#                 Shrimp          1          2          1          0          0          0
#                  Sushi          1          1          1          0      0.332      0.265
#              Vegetable         26         53     0.0941      0.113     0.0922     0.0267
# Speed: 2.1ms preprocess, 109.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs\detect\val
# array([   0.015431,    0.034109,   0.0015308,    0.034109,   0.0018143,    0.038043,   0.0029895,           0,    0.060463,           0,           0,   0.0029301,     0.15364,           0,    0.075493,     0.02616,   0.0052964,   0.0063253,           0,           0,     0.26533,    0.034109,    0.026739,    0.034109])

# %%
#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train2/weights/best.pt')

# Run inference 
model.predict('test_images', save=True, imgsz=640, conf=0.2)
# Out:
# image 1/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009513_jpg.rf.59878f10bf044a990e34760dcf772371.jpg: 640x640 1 Fruit, 227.1ms
# image 2/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009624_jpg.rf.0934dec28ce8532fada70163f93297be.jpg: 640x640 1 Vegetable, 247.6ms
# image 3/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009631_jpg.rf.9b9adde8eaad764ab3564c37c9e3b7d4.jpg: 640x640 (no detections), 189.6ms
# image 4/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009689_jpg.rf.81f4fbdca6a18fa42a908a860a2c0cb3.jpg: 640x640 1 Noodle, 193.2ms
# image 5/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009775_jpg.rf.26bc12b8d6ee5bb5ff245ea80d9b27e7.jpg: 640x640 2 Drinks, 226.3ms
# image 6/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009852_jpg.rf.fd2614985b3efb65f19fc4aa3255b07c.jpg: 640x640 1 Noodle, 147.2ms
# image 7/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\010043_jpg.rf.6b26fb73f2052b0511085943cc1dd2ba.jpg: 640x640 (no detections), 133.5ms
# image 8/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\010054_jpg.rf.6efd8af06aae4304ae24d14697679c3d.jpg: 640x640 1 Pizza, 139.5ms
# image 9/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\010086_jpg.rf.cb0f8aaa0ac2716af0a5128c2d6e5504.jpg: 640x640 1 Drink, 139.8ms
# image 10/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\010090_jpg.rf.69f84e97d6d4e49c93ecfaed231b5e46.jpg: 640x640 (no detections), 153.3ms
# Speed: 10.8ms preprocess, 179.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[ 86, 109, 135],
#          [ 97, 120, 146],
#          [115, 136, 163],
#          ...,
#          [199, 204, 213],
#          [198, 203, 212],
#          [198, 203, 212]],
#
#         [[ 90, 113, 139],
#          [ 95, 118, 144],
#          [106, 127, 154],
#          ...,
#          [199, 204, 213],
#          [198, 203, 212],
#          [198, 203, 212]],
#
#         [[ 92, 115, 141],
#          [ 92, 115, 141],
#          [ 98, 120, 145],
#          ...,
#          [199, 204, 213],
#          [198, 203, 212],
#          [198, 203, 212]],
#
#         ...,
#
#         [[194, 203, 212],
#          [195, 204, 213],
#          [196, 205, 214],
#          ...,
#          [139, 159, 177],
#          [138, 158, 176],
#          [138, 158, 176]],
#
#         [[194, 203, 212],
#          [195, 204, 213],
#          [196, 205, 214],
#          ...,
#          [135, 155, 173],
#          [138, 158, 176],
#          [140, 160, 178]],
#
#         [[193, 202, 211],
#          [195, 204, 213],
#          [197, 206, 215],
#          ...,
#          [132, 152, 170],
#          [137, 157, 175],
#          [142, 162, 180]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009513_jpg.rf.59878f10bf044a990e34760dcf772371.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 10.19820000146865, 'inference': 227.10379999989527, 'postprocess': 1.7484999989392236},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[ 46, 108, 186],
#          [ 51, 113, 191],
#          [ 55, 117, 195],
#          ...,
#          [163, 122,  99],
#          [177, 136, 114],
#          [177, 136, 114]],
#
#         [[ 49, 111, 189],
#          [ 53, 115, 193],
#          [ 56, 118, 196],
#          ...,
#          [161, 120,  97],
#          [167, 126, 104],
#          [165, 124, 102]],
#
#         [[ 54, 116, 194],
#          [ 56, 118, 196],
#          [ 58, 120, 198],
#          ...,
#          [159, 118,  96],
#          [160, 119,  97],
#          [158, 117,  95]],
#
#         ...,
#
#         [[227, 230, 238],
#          [229, 232, 240],
#          [231, 233, 241],
#          ...,
#          [ 33,  38,  53],
#          [ 40,  43,  57],
#          [ 60,  63,  77]],
#
#         [[231, 234, 242],
#          [228, 231, 239],
#          [231, 233, 241],
#          ...,
#          [ 42,  45,  60],
#          [ 53,  56,  70],
#          [ 40,  43,  57]],
#
#         [[234, 237, 245],
#          [227, 230, 238],
#          [231, 233, 241],
#          ...,
#          [ 57,  60,  75],
#          [ 70,  73,  87],
#          [ 27,  30,  44]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009624_jpg.rf.0934dec28ce8532fada70163f93297be.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 36.95480000169482, 'inference': 247.55569999979343, 'postprocess': 1.8988000010722317},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[156, 166, 184],
#          [156, 166, 184],
#          [156, 166, 184],
#          ...,
#          [ 94, 126, 175],
#          [ 93, 125, 174],
#          [ 92, 124, 173]],
#
#         [[154, 164, 182],
#          [155, 165, 183],
#          [155, 165, 183],
#          ...,
#          [100, 132, 181],
#          [ 99, 131, 180],
#          [ 99, 131, 180]],
#
#         [[152, 162, 180],
#          [153, 163, 181],
#          [152, 162, 180],
#          ...,
#          [ 99, 131, 180],
#          [100, 132, 181],
#          [100, 132, 181]],
#
#         ...,
#
#         [[156, 199, 250],
#          [153, 196, 247],
#          [151, 194, 245],
#          ...,
#          [ 23,  10,  12],
#          [ 21,   8,  10],
#          [ 19,   6,   8]],
#
#         [[156, 199, 250],
#          [152, 195, 246],
#          [146, 190, 243],
#          ...,
#          [ 26,  13,  15],
#          [ 24,  11,  13],
#          [ 21,   8,  10]],
#
#         [[156, 199, 250],
#          [151, 194, 245],
#          [144, 188, 241],
#          ...,
#          [ 25,  12,  14],
#          [ 22,   9,  11],
#          [ 20,   7,   9]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009631_jpg.rf.9b9adde8eaad764ab3564c37c9e3b7d4.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 6.4289000001735985, 'inference': 189.572399998724, 'postprocess': 1.0139000005437993},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[ 15,  95, 196],
#          [ 15,  95, 196],
#          [ 14,  96, 197],
#          ...,
#          [  9,  55, 143],
#          [  9,  55, 143],
#          [  9,  55, 143]],
#
#         [[ 16,  96, 197],
#          [ 17,  97, 198],
#          [ 15,  97, 198],
#          ...,
#          [  8,  54, 142],
#          [  8,  54, 142],
#          [  8,  54, 142]],
#
#         [[ 18,  98, 199],
#          [ 18,  98, 199],
#          [ 18,  98, 199],
#          ...,
#          [  6,  52, 140],
#          [  6,  52, 140],
#          [  6,  52, 140]],
#
#         ...,
#
#         [[ 63,  83, 124],
#          [ 62,  82, 123],
#          [ 60,  82, 123],
#          ...,
#          [ 37,  71, 125],
#          [ 40,  74, 128],
#          [ 41,  75, 129]],
#
#         [[ 62,  82, 123],
#          [ 61,  81, 122],
#          [ 61,  81, 122],
#          ...,
#          [ 37,  71, 125],
#          [ 40,  74, 128],
#          [ 41,  75, 129]],
#
#         [[ 61,  81, 122],
#          [ 61,  81, 122],
#          [ 60,  80, 121],
#          ...,
#          [ 37,  71, 125],
#          [ 39,  73, 127],
#          [ 41,  75, 129]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009689_jpg.rf.81f4fbdca6a18fa42a908a860a2c0cb3.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 7.611299999553012, 'inference': 193.2295000005979, 'postprocess': 1.7506000003777444},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[135, 147, 149],
#          [134, 146, 148],
#          [133, 143, 150],
#          ...,
#          [  0,  13,  50],
#          [  0,  13,  50],
#          [  0,  14,  51]],
#
#         [[135, 147, 149],
#          [134, 146, 148],
#          [133, 143, 150],
#          ...,
#          [  0,  13,  50],
#          [  0,  13,  50],
#          [  0,  14,  51]],
#
#         [[135, 147, 149],
#          [134, 146, 148],
#          [133, 143, 150],
#          ...,
#          [  0,  15,  51],
#          [  0,  16,  52],
#          [  1,  17,  53]],
#
#         ...,
#
#         [[199, 211, 221],
#          [199, 211, 221],
#          [199, 211, 221],
#          ...,
#          [205, 217, 227],
#          [204, 216, 226],
#          [204, 216, 226]],
#
#         [[199, 211, 221],
#          [199, 211, 221],
#          [199, 211, 221],
#          ...,
#          [208, 220, 230],
#          [207, 219, 229],
#          [207, 219, 229]],
#
#         [[199, 211, 221],
#          [199, 211, 221],
#          [199, 211, 221],
#          ...,
#          [213, 225, 235],
#          [213, 225, 235],
#          [214, 226, 236]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009775_jpg.rf.26bc12b8d6ee5bb5ff245ea80d9b27e7.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 8.04710000011255, 'inference': 226.30909999861615, 'postprocess': 2.298700001119869},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[238, 242, 243],
#          [238, 242, 243],
#          [238, 242, 243],
#          ...,
#          [ 71, 119, 215],
#          [ 64, 112, 208],
#          [ 56, 104, 199]],
#
#         [[238, 242, 243],
#          [238, 242, 243],
#          [238, 242, 243],
#          ...,
#          [ 62, 111, 209],
#          [ 60, 108, 204],
#          [ 52, 102, 198]],
#
#         [[238, 242, 243],
#          [238, 242, 243],
#          [238, 242, 243],
#          ...,
#          [ 52, 101, 203],
#          [ 52, 101, 201],
#          [ 49, 100, 197]],
#
#         ...,
#
#         [[237, 242, 241],
#          [237, 242, 241],
#          [237, 242, 241],
#          ...,
#          [194, 191, 193],
#          [175, 174, 176],
#          [147, 146, 148]],
#
#         [[236, 242, 241],
#          [236, 242, 241],
#          [236, 242, 241],
#          ...,
#          [158, 155, 157],
#          [137, 136, 138],
#          [109, 108, 110]],
#
#         [[236, 242, 241],
#          [236, 242, 241],
#          [236, 242, 241],
#          ...,
#          [145, 142, 144],
#          [142, 141, 143],
#          [132, 131, 133]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\009852_jpg.rf.fd2614985b3efb65f19fc4aa3255b07c.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 6.468000003224006, 'inference': 147.2195999995165, 'postprocess': 1.6291999963868875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[ 66,  94, 111],
#          [ 67,  95, 112],
#          [ 71,  97, 114],
#          ...,
#          [ 45,  43,  49],
#          [ 45,  43,  49],
#          [ 44,  42,  48]],
#
#         [[ 66,  94, 111],
#          [ 67,  95, 112],
#          [ 71,  97, 114],
#          ...,
#          [ 44,  42,  48],
#          [ 43,  41,  47],
#          [ 42,  40,  46]],
#
#         [[ 69,  95, 112],
#          [ 69,  95, 112],
#          [ 70,  96, 113],
#          ...,
#          [ 43,  41,  47],
#          [ 41,  39,  45],
#          [ 40,  38,  44]],
#
#         ...,
#
#         [[166, 174, 191],
#          [166, 174, 191],
#          [166, 174, 191],
#          ...,
#          [ 75,  75,  87],
#          [ 74,  74,  86],
#          [ 73,  73,  85]],
#
#         [[167, 174, 191],
#          [167, 174, 191],
#          [167, 174, 191],
#          ...,
#          [ 78,  78,  90],
#          [ 76,  76,  88],
#          [ 75,  75,  87]],
#
#         [[167, 174, 191],
#          [167, 174, 191],
#          [166, 173, 190],
#          ...,
#          [ 79,  79,  91],
#          [ 77,  77,  89],
#          [ 76,  76,  88]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\010043_jpg.rf.6b26fb73f2052b0511085943cc1dd2ba.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 9.96129999839468, 'inference': 133.52500000110012, 'postprocess': 0.9468000025663059},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[216, 225, 234],
#          [216, 225, 234],
#          [216, 225, 234],
#          ...,
#          [215, 224, 233],
#          [217, 226, 235],
#          [218, 227, 236]],
#
#         [[216, 225, 234],
#          [216, 225, 234],
#          [217, 226, 235],
#          ...,
#          [216, 225, 234],
#          [217, 226, 235],
#          [217, 226, 235]],
#
#         [[216, 225, 234],
#          [217, 226, 235],
#          [217, 226, 235],
#          ...,
#          [216, 225, 234],
#          [217, 226, 235],
#          [217, 226, 235]],
#
#         ...,
#
#         [[204, 209, 218],
#          [205, 210, 219],
#          [205, 210, 219],
#          ...,
#          [202, 213, 221],
#          [202, 213, 221],
#          [202, 213, 221]],
#
#         [[205, 210, 219],
#          [206, 211, 220],
#          [206, 211, 220],
#          ...,
#          [202, 213, 221],
#          [202, 213, 221],
#          [202, 213, 221]],
#
#         [[206, 211, 220],
#          [206, 211, 220],
#          [207, 212, 221],
#          ...,
#          [202, 213, 221],
#          [202, 213, 221],
#          [202, 213, 221]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\010054_jpg.rf.6efd8af06aae4304ae24d14697679c3d.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 6.403899998986162, 'inference': 139.47710000138613, 'postprocess': 1.8959000008180737},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[176, 166, 178],
#          [182, 172, 184],
#          [183, 173, 185],
#          ...,
#          [193, 185, 192],
#          [192, 184, 191],
#          [185, 177, 184]],
#
#         [[180, 170, 182],
#          [183, 173, 185],
#          [182, 172, 184],
#          ...,
#          [194, 186, 193],
#          [193, 185, 192],
#          [188, 180, 187]],
#
#         [[183, 175, 186],
#          [182, 174, 185],
#          [177, 169, 180],
#          ...,
#          [193, 185, 192],
#          [193, 185, 192],
#          [189, 181, 188]],
#
#         ...,
#
#         [[101, 120, 153],
#          [ 95, 114, 147],
#          [ 89, 108, 141],
#          ...,
#          [ 95, 121, 167],
#          [ 93, 122, 167],
#          [ 92, 121, 166]],
#
#         [[ 92, 111, 144],
#          [ 89, 108, 141],
#          [ 85, 104, 137],
#          ...,
#          [ 97, 126, 171],
#          [ 94, 122, 169],
#          [ 90, 118, 165]],
#
#         [[ 76,  95, 128],
#          [ 78,  97, 130],
#          [ 79,  98, 131],
#          ...,
#          [ 96, 125, 170],
#          [ 91, 119, 166],
#          [ 83, 111, 158]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\010086_jpg.rf.cb0f8aaa0ac2716af0a5128c2d6e5504.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 7.415100000798702, 'inference': 139.8367000001599, 'postprocess': 3.374600000825012},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bread', 1: 'Burger', 2: 'Cake', 3: 'Chocolate', 4: 'Dairy', 5: 'Drink', 6: 'Egg', 7: 'Fish', 8: 'Fruit', 9: 'Lasagne', 10: 'Legume', 11: 'Meat', 12: 'Noodle', 13: 'Nut', 14: 'Pastry', 15: 'Pizza', 16: 'Potato', 17: 'Rice', 18: 'Sauce', 19: 'Shrimp', 20: 'Sushi', 21: 'Tofu', 22: 'Vegetable', 23: 'biscuits'}
#  obb: None
#  orig_img: array([[[ 92, 110, 147],
#          [ 90, 109, 146],
#          [ 75,  95, 136],
#          ...,
#          [ 57,  92, 148],
#          [ 21,  52, 107],
#          [ 60,  91, 146]],
#
#         [[ 90, 107, 146],
#          [ 87, 106, 144],
#          [ 70,  92, 133],
#          ...,
#          [ 64,  99, 155],
#          [ 29,  63, 117],
#          [ 48,  79, 134]],
#
#         [[ 86, 104, 145],
#          [ 80, 100, 141],
#          [ 64,  85, 130],
#          ...,
#          [ 72, 107, 163],
#          [ 55,  89, 143],
#          [ 48,  82, 136]],
#
#         ...,
#
#         [[ 86, 130, 184],
#          [ 86, 130, 184],
#          [ 83, 127, 181],
#          ...,
#          [ 75, 128, 195],
#          [ 76, 129, 196],
#          [ 74, 127, 194]],
#
#         [[ 90, 136, 190],
#          [ 87, 133, 187],
#          [ 82, 128, 182],
#          ...,
#          [ 73, 124, 194],
#          [ 72, 123, 193],
#          [ 68, 119, 189]],
#
#         [[ 97, 143, 197],
#          [ 92, 138, 192],
#          [ 87, 133, 187],
#          ...,
#          [ 83, 134, 204],
#          [ 80, 131, 201],
#          [ 73, 124, 194]]], dtype=uint8)
#  orig_shape: (416, 416)
#  path: 'C:\\Users\\mortrpestl\\Desktop\\Archives\\mortrpestl\\Recreational\\Programming\\Repos\\Object-Detection-Android-App\\test_images\\010090_jpg.rf.69f84e97d6d4e49c93ecfaed231b5e46.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict3'
#  speed: {'preprocess': 8.167599997250363, 'inference': 153.25959999972838, 'postprocess': 0.9833000003709458}]

# %%
#  Export model to tflite
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train2/weights/best.pt')  # load a custom trained model
# note: won't work on Windows because of "ai-edge-litert", use Google Colab or Linux-based environment

# Export the model
model.export(format='tflite')
# Out:
# Ultralytics 8.3.153  Python-3.12.3 torch-2.7.1+cpu CPU (AMD Ryzen 7 4700U with Radeon Graphics)
# Model summary (fused): 72 layers, 3,010,328 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs\detect\train2\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 28, 8400) (17.6 MB)
# requirements: Ultralytics requirements ['ai-edge-litert>=1.2.0', 'protobuf>=5'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "ai-edge-litert>=1.2.0" "protobuf>=5" --extra-index-url https://pypi.ngc.nvidia.com' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "ai-edge-litert>=1.2.0" "protobuf>=5" --extra-index-url https://pypi.ngc.nvidia.com' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "ai-edge-litert>=1.2.0" "protobuf>=5" --extra-index-url https://pypi.ngc.nvidia.com' returned non-zero exit status 1.
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.57...
# ONNX: export success  2.7s, saved as 'runs\detect\train2\weights\best.onnx' (11.8 MB)
# ERROR TensorFlow SavedModel: export failure 15.8s: No module named 'ai_edge_litert'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 8
#       5 model = YOLO('runs/detect/train2/weights/best.pt')  # load a custom trained model
#       7 # Export the model
# ----> 8 model.export(format='tflite')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:734, in Model.export(self, **kwargs)
#     726 custom = {
#     727     "imgsz": self.model.args["imgsz"],
#     728     "batch": 1,
#    (...)    731     "verbose": False,
#     732 }  # method defaults
#     733 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# --> 734 return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\exporter.py:509, in Exporter.__call__(self, model)
#     507 if is_tf_format:  # TensorFlow formats
#     508     self.args.int8 |= edgetpu
# --> 509     f[5], keras_model = self.export_saved_model()
#     510     if pb or tfjs:  # pb prerequisite to tfjs
#     511         f[6], _ = self.export_pb(keras_model=keras_model)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\exporter.py:197, in try_export.<locals>.outer_func(*args, **kwargs)
#     195 except Exception as e:
#     196     LOGGER.error(f"{prefix} export failure {dt.t:.1f}s: {e}")
# --> 197     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\exporter.py:192, in try_export.<locals>.outer_func(*args, **kwargs)
#     190 try:
#     191     with Profile() as dt:
# --> 192         f, model = inner_func(*args, **kwargs)
#     193     LOGGER.info(f"{prefix} export success ✅ {dt.t:.1f}s, saved as '{f}' ({file_size(f):.1f} MB)")
#     194     return f, model
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\exporter.py:1013, in Exporter.export_saved_model(self, prefix)
#    1010         np.save(str(tmp_file), images.numpy().astype(np.float32))  # BHWC
#    1011         np_data = [["images", tmp_file, [[[[0, 0, 0]]]], [[[[255, 255, 255]]]]]]
# -> 1013 import onnx2tf  # scoped for after ONNX export for reduced conflict during import
#    1015 LOGGER.info(f"{prefix} starting TFLite export with onnx2tf {onnx2tf.__version__}...")
#    1016 keras_model = onnx2tf.convert(
#    1017     input_onnx_file_path=f_onnx,
#    1018     output_folder_path=str(f),
#    (...)   1027     optimization_for_gpu_delegate=True,
#    1028 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnx2tf\__init__.py:1
# ----> 1 from onnx2tf.onnx2tf import convert, main
#       3 __version__ = '1.27.10'
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnx2tf\onnx2tf.py:44
#      41 from argparse import ArgumentParser
#      43 import importlib
# ---> 44 from onnx2tf.utils.common_functions import (
#      45     dummy_onnx_inference,
#      46     dummy_tf_inference,
#      47     onnx_tf_tensor_validation,
#      48     weights_export,
#      49     download_test_image_data,
#      50     get_tf_model_inputs,
#      51     get_tf_model_outputs,
#      52     rewrite_tflite_inout_opname,
#      53     check_cuda_enabled,
#      54 )
#      55 from onnx2tf.utils.enums import (
#      56     CUDA_ONLY_OPS,
#      57 )
#      58 from onnx2tf.utils.logging import *
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\onnx2tf\utils\common_functions.py:20
#      18 np.random.seed(0)
#      19 import tensorflow as tf
# ---> 20 from ai_edge_litert.interpreter import Interpreter
#      21 import tf_keras
#      22 from tensorflow.python.keras.layers import Lambda
#
# ModuleNotFoundError: No module named 'ai_edge_litert'

# %%
# Prediction using custom tflite model

#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs\\detect\\train3\\weights\\best_saved_model\\best_float32.tflite')

# Run inference 
model.predict('test_images', save=True, imgsz=640, conf=0.2)

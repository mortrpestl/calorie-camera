# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.train(data='data.yaml', epochs=50, imgsz=640, device="cpu")

# %%
#validate model

from ultralytics import YOLO

model = YOLO('runs/detect/train2/weights/best.pt')

metrics = model.val()
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.152  Python-3.12.3 torch-2.7.1+cpu CPU (AMD Ryzen 7 4700U with Radeon Graphics)
# Model summary (fused): 72 layers, 3,010,328 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.40.1 ms, read: 8.715.5 MB/s, size: 23.8 KB)
# val: Scanning C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-A
# C:\Users\mortrpestl\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:15<0
#                    all         99        261      0.401     0.0668     0.0748     0.0341
#                  Bread         14         24      0.099     0.0833     0.0763     0.0154
# ...

# %%
#prediction

from ultralytics import YOLO

model = YOLO('runs/detect/train2/weights/best.pt')
model.predict('test_images', save=True, imgsz=640, conf=0.2)
# Out:
# image 1/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009513_jpg.rf.59878f10bf044a990e34760dcf772371.jpg: 640x640 1 Fruit, 227.1ms
# image 2/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009624_jpg.rf.0934dec28ce8532fada70163f93297be.jpg: 640x640 1 Vegetable, 247.6ms
# image 3/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009631_jpg.rf.9b9adde8eaad764ab3564c37c9e3b7d4.jpg: 640x640 (no detections), 189.6ms
# image 4/10 C:\Users\mortrpestl\Desktop\Archives\mortrpestl\Recreational\Programming\Repos\Object-Detection-Android-App\test_images\009689_jpg.rf.81f4fbdca6a18fa42a908a860a2c0cb3.jpg: 640x640 1 Noodle, 193.2ms
# ...

# %%
#export to TFlite
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/calorie-camera/runs/detect/train2/weights/best.pt')  # load a custom trained model
# note: won't work on Windows because of "ai-edge-litert", use Google Colab or Linux-based environment
model.export(format='tflite')
# Out:
# Ultralytics 8.3.153 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# Model summary (fused): 72 layers, 3,010,328 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/calorie-camera/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 28, 8400) (17.6 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<1.18.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.56', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 5.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# ...
# 100%|██████████| 1.11M/1.11M [00:00<00:00, 19.3MB/s]
# ...

# %%
#prediction using tflite (optional)

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/calorie-camera/runs/detect/train2/weights/best_saved_model/best_float32.tflite')

# Run inference
model.predict('/content/drive/MyDrive/calorie-camera/test_images', save=True, imgsz=640, conf=0.2)
# Out:
# Loading /content/drive/MyDrive/calorie-camera/runs/detect/train2/weights/best_saved_model/best_float32.tflite for TensorFlow Lite inference...
#
# image 1/10 /content/drive/MyDrive/calorie-camera/test_images/009513_jpg.rf.59878f10bf044a990e34760dcf772371.jpg: 640x640 1 Fruit, 132.0ms
# image 2/10 /content/drive/MyDrive/calorie-camera/test_images/009624_jpg.rf.0934dec28ce8532fada70163f93297be.jpg: 640x640 1 Vegetable, 118.0ms
# image 3/10 /content/drive/MyDrive/calorie-camera/test_images/009631_jpg.rf.9b9adde8eaad764ab3564c37c9e3b7d4.jpg: 640x640 (no detections), 128.4ms
# image 4/10 /content/drive/MyDrive/calorie-camera/test_images/009689_jpg.rf.81f4fbdca6a18fa42a908a860a2c0cb3.jpg: 640x640 1 Noodle, 125.0ms
# image 5/10 /content/drive/MyDrive/calorie-camera/test_images/009775_jpg.rf.26bc12b8d6ee5bb5ff245ea80d9b27e7.jpg: 640x640 2 Drinks, 127.0ms
# ...
